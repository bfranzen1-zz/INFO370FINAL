# %%
# Function to create a dataframe with the pages used in the kaggle dataset and their
# amount of followers, as well as the date the info was collected
import pandas as pd

# %%
fact_check = pd.read_csv('facebook-fact-check.csv')
fact_check.head()
# Out:
#         account_id           post_id    Category               Page  \
# 0  184096565021911  1035057923259100  mainstream  ABC News Politics
# 1  184096565021911  1035269309904628  mainstream  ABC News Politics
# 2  184096565021911  1035305953234297  mainstream  ABC News Politics
# 3  184096565021911  1035322636565962  mainstream  ABC News Politics
# 4  184096565021911  1035352946562931  mainstream  ABC News Politics
#
#                                             Post URL Date Published Post Type  \
# 0  https://www.facebook.com/ABCNewsPolitics/posts...     2016-09-19     video
# 1  https://www.facebook.com/ABCNewsPolitics/posts...     2016-09-19      link
# 2  https://www.facebook.com/ABCNewsPolitics/posts...     2016-09-19      link
# 3  https://www.facebook.com/ABCNewsPolitics/posts...     2016-09-19      link
# 4  https://www.facebook.com/ABCNewsPolitics/posts...     2016-09-19     video
#
#                Rating Debate  share_count  reaction_count  comment_count
# ...

# %%
def getPageFollowers():
    data = [['ABC News Politics', 922117],['Addicting Info', 1245232],['CNN Politics', 2774048], ['Eagle Rising'],
           ['Freedom Daily'], ['Occupy Democrats', 7576361], ['Politico', 1834560], ['Right Wing News', 5227], ['The Other 98%', 
            6080688]]
    df = pd.DataFrame(data,columns=['Page','Followers'],dtype='int64')
    date = '11/27/2018'
    return df, date
followers, date = getPageFollowers()
followers
# Out:
#                 Page  Followers
# 0  ABC News Politics   922117.0
# 1     Addicting Info  1245232.0
# 2       CNN Politics  2774048.0
# 3       Eagle Rising        NaN
# 4      Freedom Daily        NaN
# 5   Occupy Democrats  7576361.0
# 6           Politico  1834560.0
# 7    Right Wing News     5227.0
# 8      The Other 98%  6080688.0
